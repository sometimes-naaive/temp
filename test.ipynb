# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import random

# %%
#display images
img1 = Image.open('./test/lena.png')

plt.imshow(img1)
plt.title('photo1')
plt.axis('off')

plt.show()

# %%
#read all the images in the folder 
imglist = [] 
for filename in os.listdir('./test'):
    img = Image.open("./test/" + filename)
imglist.append(img)        

#store them in numpy arrays        
img_array_list = []
img_array_list.append(np.array(img))  

#randomly select one image
sample1 = np.array(random.choice(imglist).convert('L'))

#display a histogram of its brightness values.
plt.hist(sample1.ravel(),256)
plt.show()
